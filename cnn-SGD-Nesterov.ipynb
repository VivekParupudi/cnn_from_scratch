# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
from numpy import *
import cv2
import matplotlib.pyplot as plt

# %%
def step_sgd_nesterov(parameter_to_update, gradient, v, decay_factor=0.9, learning_rate=0.001):

  v = (decay_factor * v) + (1 - decay_factor) * gradient
  
  parameter_to_update -= learning_rate * v

  return [v, parameter_to_update]

def run_sgd_nesterov(parameter, gradient, initial_v, decay_factor=0.9, learning_rate=0.001, num_iterations=1):

  v = initial_v

  for i in range(num_iterations):
    v, parameter = step_sgd_nesterov(parameter, gradient, v, decay_factor, learning_rate)
  
  return [v, parameter]

# %% [markdown]
# CNN CODE

# %%
class Conv:
  def __init__(self, num_filters, filter_size):
    self.num_filters = num_filters
    self.filter_size = filter_size
    self.conv_filter = np.random.randn(num_filters, filter_size, filter_size)/(filter_size * filter_size) # normalize the values

    # initialize for SGD-Mom
    self.sgd_nest_initial_v = 0
    self.sgd_nest_decay_factor = 0.9

  def image_region(self, image):
    # generator function
    height, width = image.shape
    self.image = image

    # need to vectorize this
    for i in range (height - self.filter_size + 1):
      for j in range (width - self.filter_size + 1):
        image_patch = image [i: (i + self.filter_size), j: (j + self.filter_size)]
        yield image_patch, i, j # stores all image patches
  
  def forward_prop(self, image):
    height, width = image.shape
    conv_out = np.zeros((height - self.filter_size + 1, width - self.filter_size + 1, self.num_filters))
    
    # need to vectorize this
    for image_patch, i, j in self.image_region(image):
      conv_out[i, j] = np.sum(image_patch * self.conv_filter, axis = (1, 2))
    return conv_out

  def back_prop(self, dL_dout, learning_rate, optimizer):

    """
    add input parameter called optimizer w/ values ('gd', 'sgd', 'sgd_mom', 'sgd_nesterov', 'adam', 'rmsprop', etc...)
    check optimizer param against the input string and run the appropriate algorithm
    should be consistent w/ the value passed to the softmax layer

    if optimizer == 'gd':
      run_gd()
    
    if optimizer == 'sgd':
      run_sgd()

    ...
    """
    dL_dF_params = np.zeros(self.conv_filter.shape)

    # need to vectorize this
    for image_patch, i, j in self.image_region(self.image):
      for k in range(self.num_filters):
        dL_dF_params[k] += image_patch * dL_dout[i,j,k]

    # stochastic gradient descent
    if optimizer == 'sgd-nesterov':
      self.sgd_nest_initial_v, self.conv_filter = run_sgd_nesterov(self.conv_filter, dL_dF_params, initial_v=self.sgd_nest_initial_v, decay_factor=self.sgd_nest_decay_factor, learning_rate=0.001, num_iterations=1)

    # ADD OTHER OPTIMIZERS HERE
    
    return dL_dF_params

# %%
class Max_Pool:
  def __init__(self, filter_size):
    self.filter_size = filter_size
  
  def image_region(self, image):
    new_height = image.shape[0] // self.filter_size
    new_width = image.shape[1] // self.filter_size
    self.image = image

    # need to vectorize this
    for i in range(new_height):
      for j in range(new_width):
        image_patch = image[(i*self.filter_size) : (i*self.filter_size + self.filter_size) , (j*self.filter_size) : (j*self.filter_size + self.filter_size)]
        yield image_patch, i, j

  def forward_prop(self, image):
    height, width, num_filters = image.shape
    output = np.zeros((height // self.filter_size, width // self.filter_size, num_filters))

    # need to vectorize this
    for image_patch, i, j in self.image_region(image):
      output[i, j] = np.amax(image_patch, axis=(0,1))

    return output 

  def back_prop(self, dL_dout):
    dL_dmax_pool = np.zeros(self.image.shape)
    for image_patch, i, j in self.image_region(self.image):
      height, width, num_filters = image_patch.shape
      maximum_val = np.amax(image_patch, axis=(0,1))

      # need to vectorize this 
      for i1 in range(height):
        for j1 in range(width):
          for k1 in range(num_filters):
            if image_patch[i1, j1, k1] == maximum_val[k1]:
              dL_dmax_pool[i*self.filter_size + i1, j*self.filter_size + j1, k1] = dL_dout[i, j, k1]
      
      return dL_dmax_pool

# %%
class SoftMax:
  def __init__(self, input_node, softmax_node):
    self.weight = np.random.randn(input_node, softmax_node) / input_node
    self.bias = np.zeros(softmax_node)

    # initialize for SGD-Nesterov
    self.sgd_nest_initial_v_w = 0
    self.sgd_nest_initial_v_b = 0
    self.sgd_nest_decay_factor = 0.9

  def forward_prop(self, image):
    self.orig_image_shape = image.shape
    modified_image = image.flatten()
    self.modified_input = modified_image
    output_val = np.dot(modified_image, self.weight) + self.bias
    self.out = output_val
    exp_out = np.exp(output_val)
    return exp_out/np.sum(exp_out, axis = 0)
  
  def back_prop(self, dL_dout, learning_rate, optimizer):

    """
    add input parameter called optimizer w/ values ('gd', 'sgd', 'sgd_mom', 'sgd_nesterov', 'adam', 'rmsprop', etc...)
    check optimizer param against the input string and run the appropriate algorithm
    should be consistent w/ the value passed to the conv layer

    if optimizer == 'gd':
      run_gd()
    """

    for i, grad in enumerate(dL_dout):
      if grad == 0:
        continue
    
      transformation_eq = np.exp(self.out)
      S_total = np.sum(transformation_eq)

      # Gradients w/ respect to output (z)
      dy_dz = -transformation_eq[i]*transformation_eq / (S_total ** 2)
      dy_dz[i] = transformation_eq[i]*(S_total - transformation_eq[i]) / (S_total ** 2)

      # Gradients of totals against weights/biases/input
      dz_dw = self.modified_input # against weights
      dz_db = 1 # against biases
      dz_d_inp = self.weight # against input

      # Gradients of loss against totals
      dL_dz = grad * dy_dz

      # Gradients of loss against weights/biases/input
      dL_dw = dz_dw[np.newaxis].T @ dL_dz[np.newaxis] # against weights (@ => matrix multiplication operator)
      dL_db = dL_dz * dz_db # against biases
      dL_d_inp = dz_d_inp @ dL_dz # against input

      if optimizer == 'sgd-nesterov':
        # update weights
        self.sgd_nest_initial_v_w, self.weight = run_sgd_nesterov(self.weight, dL_dw, initial_v=self.sgd_nest_initial_v_w, decay_factor=self.sgd_nest_decay_factor, learning_rate=0.001, num_iterations=1)

        # update biases
        self.sgd_nest_initial_v_b, self.bias = run_sgd_nesterov(self.bias, dL_db, initial_v=self.sgd_nest_initial_v_b, decay_factor=self.sgd_nest_decay_factor, learning_rate=0.001, num_iterations=1)

      # ADD OTHER OPTIMIZERS HERE

      """
      # Update weights and biases
      self.weight -= learning_rate * dL_dw 
      self.bias -= learning_rate * dL_db
      """

      return dL_d_inp.reshape(self.orig_image_shape)

# %%
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

train_images = X_train[:6000]
train_labels = y_train[:6000]
test_images = X_test[:1500]
test_labels = y_test[:1500]

conv = Conv(8, 3)
pool = Max_Pool(2)
softmax = SoftMax(13 * 13 * 8, 10)

def feed_forward(image, label):
  out = conv.forward_prop((image / 255) - 0.5)
  out = pool.forward_prop(out)
  out = softmax.forward_prop(out)

  # Calculate cross-entropy loss and accuracy
  if out[label] != 0: cross_entropy_loss = -np.log(out[label])
  else: cross_entropy_loss = 0
  if np.isnan(cross_entropy_loss) or np.isinf(cross_entropy_loss): cross_entropy_loss = 0
  accuracy = 1 if np.argmax(out) == label else 0

  return out, cross_entropy_loss, accuracy

def train(image, label, optimizer, initial_v = 0, decay_factor = 0.9, learning_rate = 0.01):

  # Forward
  out, loss, acc = feed_forward(image, label)

  # Calculate initial gradient
  v = initial_v

  gradient = np.zeros(10)
  if out[label] != 0: gradient[label] = -1 / (out[label] - (decay_factor * initial_v)) # Nesterov lookahead gradient

  v = (decay_factor * v) + (1 - decay_factor) * gradient

  # Backpropagation
  grad_back = softmax.back_prop(gradient, learning_rate, optimizer)
  grad_back = pool.back_prop(grad_back)
  grad_back = conv.back_prop(grad_back, learning_rate, optimizer)

  return v, loss, acc

# %%
import time

num_epochs = 10
optimizer = 'sgd-nesterov'
learning_rate = 0.0001
initial_v = 0

print('Training the CNN....')
start = time.time()

loss = 0
num_correct = 0
lossVals = []
accuVals = []

for epoch in range(num_epochs):
  print('Epoch %d ----> ' % (epoch + 1))

  # Shuffle the training data
  shuffle_data = np.random.permutation(len(train_images))
  train_images = train_images[shuffle_data]
  train_labels = train_labels[shuffle_data]

  # Train the CNN
  for i, (img, label) in enumerate(zip(train_images, train_labels)):
    # print progress every 100 images 
    if i % 100 == 0:
      print('%d of 100 steps: Average loss %.3f and Accuracy: %d%%' % (i + 1, loss / ((i + 1) + epoch*6000), (num_correct * 100 / ((i + 1) + epoch*6000))))

    v, l1, accu = train(img, label, optimizer, learning_rate, initial_v)
    
    lossVals.append(loss / ((i + 1) + epoch*6000))
    accuVals.append(num_correct * 100 / ((i + 1) + epoch*6000))

    loss += l1
    num_correct += accu

print(time.time()-start)
# Out:
# Training the CNN....
# Epoch 1 ---->
# 1 of 100 steps: Average loss 0.000 and Accuracy: 0%
# 101 of 100 steps: Average loss 2.266 and Accuracy: 18%
# 201 of 100 steps: Average loss 2.271 and Accuracy: 15%
# 301 of 100 steps: Average loss 2.268 and Accuracy: 21%
# 401 of 100 steps: Average loss 2.257 and Accuracy: 27%
# 501 of 100 steps: Average loss 2.247 and Accuracy: 31%
# 601 of 100 steps: Average loss 2.240 and Accuracy: 34%
# 701 of 100 steps: Average loss 2.233 and Accuracy: 35%
# 801 of 100 steps: Average loss 2.224 and Accuracy: 35%
# 901 of 100 steps: Average loss 2.216 and Accuracy: 37%
# 1001 of 100 steps: Average loss 2.209 and Accuracy: 39%
# 1101 of 100 steps: Average loss 2.200 and Accuracy: 41%
# 1201 of 100 steps: Average loss 2.191 and Accuracy: 42%
# 1301 of 100 steps: Average loss 2.182 and Accuracy: 43%
# 1401 of 100 steps: Average loss 2.174 and Accuracy: 43%
# 1501 of 100 steps: Average loss 2.167 and Accuracy: 44%
# 1601 of 100 steps: Average loss 2.157 and Accuracy: 45%
# 1701 of 100 steps: Average loss 2.148 and Accuracy: 46%
# 1801 of 100 steps: Average loss 2.138 and Accuracy: 47%
# 1901 of 100 steps: Average loss 2.130 and Accuracy: 48%
# 2001 of 100 steps: Average loss 2.119 and Accuracy: 49%
# 2101 of 100 steps: Average loss 2.110 and Accuracy: 49%
# 2201 of 100 steps: Average loss 2.103 and Accuracy: 50%
# 2301 of 100 steps: Average loss 2.096 and Accuracy: 50%
# 2401 of 100 steps: Average loss 2.086 and Accuracy: 51%
# 2501 of 100 steps: Average loss 2.078 and Accuracy: 51%
# 2601 of 100 steps: Average loss 2.071 and Accuracy: 52%
# 2701 of 100 steps: Average loss 2.064 and Accuracy: 53%
# 2801 of 100 steps: Average loss 2.056 and Accuracy: 53%
# 2901 of 100 steps: Average loss 2.049 and Accuracy: 54%
# 3001 of 100 steps: Average loss 2.041 and Accuracy: 54%
# 3101 of 100 steps: Average loss 2.034 and Accuracy: 55%
# 3201 of 100 steps: Average loss 2.026 and Accuracy: 56%
# 3301 of 100 steps: Average loss 2.018 and Accuracy: 56%
# 3401 of 100 steps: Average loss 2.011 and Accuracy: 57%
# 3501 of 100 steps: Average loss 2.003 and Accuracy: 57%
# 3601 of 100 steps: Average loss 1.996 and Accuracy: 57%
# 3701 of 100 steps: Average loss 1.989 and Accuracy: 58%
# 3801 of 100 steps: Average loss 1.981 and Accuracy: 58%
# 3901 of 100 steps: Average loss 1.976 and Accuracy: 59%
# 4001 of 100 steps: Average loss 1.970 and Accuracy: 59%
# 4101 of 100 steps: Average loss 1.962 and Accuracy: 60%
# 4201 of 100 steps: Average loss 1.954 and Accuracy: 60%
# 4301 of 100 steps: Average loss 1.946 and Accuracy: 60%
# 4401 of 100 steps: Average loss 1.939 and Accuracy: 61%
# 4501 of 100 steps: Average loss 1.932 and Accuracy: 61%
# 4601 of 100 steps: Average loss 1.925 and Accuracy: 61%
# 4701 of 100 steps: Average loss 1.919 and Accuracy: 61%
# 4801 of 100 steps: Average loss 1.913 and Accuracy: 61%
# 4901 of 100 steps: Average loss 1.906 and Accuracy: 62%
# 5001 of 100 steps: Average loss 1.899 and Accuracy: 62%
# 5101 of 100 steps: Average loss 1.892 and Accuracy: 62%
# 5201 of 100 steps: Average loss 1.886 and Accuracy: 63%
# 5301 of 100 steps: Average loss 1.880 and Accuracy: 63%
# 5401 of 100 steps: Average loss 1.875 and Accuracy: 63%
# 5501 of 100 steps: Average loss 1.868 and Accuracy: 63%
# 5601 of 100 steps: Average loss 1.861 and Accuracy: 64%
# 5701 of 100 steps: Average loss 1.855 and Accuracy: 64%
# 5801 of 100 steps: Average loss 1.848 and Accuracy: 64%
# 5901 of 100 steps: Average loss 1.841 and Accuracy: 64%
# Epoch 2 ---->
# 1 of 100 steps: Average loss 1.833 and Accuracy: 65%
# 101 of 100 steps: Average loss 1.827 and Accuracy: 65%
# 201 of 100 steps: Average loss 1.821 and Accuracy: 65%
# 301 of 100 steps: Average loss 1.815 and Accuracy: 65%
# 401 of 100 steps: Average loss 1.809 and Accuracy: 65%
# 501 of 100 steps: Average loss 1.803 and Accuracy: 65%
# 601 of 100 steps: Average loss 1.796 and Accuracy: 66%
# 701 of 100 steps: Average loss 1.790 and Accuracy: 66%
# 801 of 100 steps: Average loss 1.784 and Accuracy: 66%
# 901 of 100 steps: Average loss 1.779 and Accuracy: 66%
# 1001 of 100 steps: Average loss 1.773 and Accuracy: 66%
# 1101 of 100 steps: Average loss 1.767 and Accuracy: 66%
# 1201 of 100 steps: Average loss 1.761 and Accuracy: 67%
# 1301 of 100 steps: Average loss 1.756 and Accuracy: 67%
# 1401 of 100 steps: Average loss 1.750 and Accuracy: 67%
# 1501 of 100 steps: Average loss 1.745 and Accuracy: 67%
# 1601 of 100 steps: Average loss 1.739 and Accuracy: 67%
# 1701 of 100 steps: Average loss 1.735 and Accuracy: 67%
# 1801 of 100 steps: Average loss 1.729 and Accuracy: 67%
# 1901 of 100 steps: Average loss 1.724 and Accuracy: 68%
# 2001 of 100 steps: Average loss 1.718 and Accuracy: 68%
# 2101 of 100 steps: Average loss 1.714 and Accuracy: 68%
# 2201 of 100 steps: Average loss 1.709 and Accuracy: 68%
# 2301 of 100 steps: Average loss 1.704 and Accuracy: 68%
# 2401 of 100 steps: Average loss 1.699 and Accuracy: 68%
# 2501 of 100 steps: Average loss 1.694 and Accuracy: 68%
# 2601 of 100 steps: Average loss 1.690 and Accuracy: 69%
# 2701 of 100 steps: Average loss 1.686 and Accuracy: 69%
# 2801 of 100 steps: Average loss 1.681 and Accuracy: 69%
# 2901 of 100 steps: Average loss 1.675 and Accuracy: 69%
# 3001 of 100 steps: Average loss 1.670 and Accuracy: 69%
# 3101 of 100 steps: Average loss 1.667 and Accuracy: 69%
# 3201 of 100 steps: Average loss 1.662 and Accuracy: 69%
# 3301 of 100 steps: Average loss 1.657 and Accuracy: 70%
# 3401 of 100 steps: Average loss 1.652 and Accuracy: 70%
# 3501 of 100 steps: Average loss 1.648 and Accuracy: 70%
# 3601 of 100 steps: Average loss 1.643 and Accuracy: 70%
# 3701 of 100 steps: Average loss 1.639 and Accuracy: 70%
# 3801 of 100 steps: Average loss 1.634 and Accuracy: 70%
# 3901 of 100 steps: Average loss 1.630 and Accuracy: 70%
# 4001 of 100 steps: Average loss 1.626 and Accuracy: 70%
# 4101 of 100 steps: Average loss 1.622 and Accuracy: 70%
# 4201 of 100 steps: Average loss 1.617 and Accuracy: 70%
# 4301 of 100 steps: Average loss 1.613 and Accuracy: 70%
# 4401 of 100 steps: Average loss 1.608 and Accuracy: 71%
# 4501 of 100 steps: Average loss 1.604 and Accuracy: 71%
# 4601 of 100 steps: Average loss 1.600 and Accuracy: 71%
# 4701 of 100 steps: Average loss 1.596 and Accuracy: 71%
# 4801 of 100 steps: Average loss 1.593 and Accuracy: 71%
# 4901 of 100 steps: Average loss 1.589 and Accuracy: 71%
# 5001 of 100 steps: Average loss 1.584 and Accuracy: 71%
# 5101 of 100 steps: Average loss 1.580 and Accuracy: 71%
# 5201 of 100 steps: Average loss 1.577 and Accuracy: 71%
# 5301 of 100 steps: Average loss 1.573 and Accuracy: 71%
# 5401 of 100 steps: Average loss 1.568 and Accuracy: 71%
# 5501 of 100 steps: Average loss 1.565 and Accuracy: 72%
# 5601 of 100 steps: Average loss 1.561 and Accuracy: 72%
# 5701 of 100 steps: Average loss 1.557 and Accuracy: 72%
# 5801 of 100 steps: Average loss 1.553 and Accuracy: 72%
# 5901 of 100 steps: Average loss 1.549 and Accuracy: 72%
# Epoch 3 ---->
# 1 of 100 steps: Average loss 1.545 and Accuracy: 72%
# 101 of 100 steps: Average loss 1.541 and Accuracy: 72%
# 201 of 100 steps: Average loss 1.537 and Accuracy: 72%
# 301 of 100 steps: Average loss 1.534 and Accuracy: 72%
# 401 of 100 steps: Average loss 1.530 and Accuracy: 72%
# 501 of 100 steps: Average loss 1.526 and Accuracy: 72%
# 601 of 100 steps: Average loss 1.522 and Accuracy: 72%
# 701 of 100 steps: Average loss 1.518 and Accuracy: 73%
# 801 of 100 steps: Average loss 1.514 and Accuracy: 73%
# 901 of 100 steps: Average loss 1.511 and Accuracy: 73%
# 1001 of 100 steps: Average loss 1.507 and Accuracy: 73%
# 1101 of 100 steps: Average loss 1.504 and Accuracy: 73%
# 1201 of 100 steps: Average loss 1.501 and Accuracy: 73%
# 1301 of 100 steps: Average loss 1.498 and Accuracy: 73%
# 1401 of 100 steps: Average loss 1.494 and Accuracy: 73%
# 1501 of 100 steps: Average loss 1.491 and Accuracy: 73%
# 1601 of 100 steps: Average loss 1.488 and Accuracy: 73%
# 1701 of 100 steps: Average loss 1.484 and Accuracy: 73%
# 1801 of 100 steps: Average loss 1.481 and Accuracy: 73%
# 1901 of 100 steps: Average loss 1.477 and Accuracy: 73%
# 2001 of 100 steps: Average loss 1.474 and Accuracy: 73%
# 2101 of 100 steps: Average loss 1.471 and Accuracy: 74%
# 2201 of 100 steps: Average loss 1.468 and Accuracy: 74%
# 2301 of 100 steps: Average loss 1.464 and Accuracy: 74%
# 2401 of 100 steps: Average loss 1.461 and Accuracy: 74%
# 2501 of 100 steps: Average loss 1.458 and Accuracy: 74%
# 2601 of 100 steps: Average loss 1.455 and Accuracy: 74%
# 2701 of 100 steps: Average loss 1.451 and Accuracy: 74%
# 2801 of 100 steps: Average loss 1.449 and Accuracy: 74%
# 2901 of 100 steps: Average loss 1.445 and Accuracy: 74%
# 3001 of 100 steps: Average loss 1.443 and Accuracy: 74%
# 3101 of 100 steps: Average loss 1.439 and Accuracy: 74%
# 3201 of 100 steps: Average loss 1.436 and Accuracy: 74%
# 3301 of 100 steps: Average loss 1.433 and Accuracy: 74%
# 3401 of 100 steps: Average loss 1.430 and Accuracy: 74%
# 3501 of 100 steps: Average loss 1.428 and Accuracy: 74%
# 3601 of 100 steps: Average loss 1.424 and Accuracy: 74%
# 3701 of 100 steps: Average loss 1.421 and Accuracy: 75%
# 3801 of 100 steps: Average loss 1.418 and Accuracy: 75%
# 3901 of 100 steps: Average loss 1.415 and Accuracy: 75%
# 4001 of 100 steps: Average loss 1.412 and Accuracy: 75%
# 4101 of 100 steps: Average loss 1.409 and Accuracy: 75%
# 4201 of 100 steps: Average loss 1.406 and Accuracy: 75%
# 4301 of 100 steps: Average loss 1.403 and Accuracy: 75%
# 4401 of 100 steps: Average loss 1.400 and Accuracy: 75%
# 4501 of 100 steps: Average loss 1.397 and Accuracy: 75%
# 4601 of 100 steps: Average loss 1.394 and Accuracy: 75%
# 4701 of 100 steps: Average loss 1.392 and Accuracy: 75%
# 4801 of 100 steps: Average loss 1.388 and Accuracy: 75%
# 4901 of 100 steps: Average loss 1.386 and Accuracy: 75%
# 5001 of 100 steps: Average loss 1.383 and Accuracy: 75%
# 5101 of 100 steps: Average loss 1.380 and Accuracy: 75%
# 5201 of 100 steps: Average loss 1.379 and Accuracy: 75%
# 5301 of 100 steps: Average loss 1.376 and Accuracy: 75%
# 5401 of 100 steps: Average loss 1.374 and Accuracy: 75%
# 5501 of 100 steps: Average loss 1.371 and Accuracy: 76%
# 5601 of 100 steps: Average loss 1.368 and Accuracy: 76%
# 5701 of 100 steps: Average loss 1.366 and Accuracy: 76%
# 5801 of 100 steps: Average loss 1.364 and Accuracy: 76%
# 5901 of 100 steps: Average loss 1.361 and Accuracy: 76%
# Epoch 4 ---->
# 1 of 100 steps: Average loss 1.358 and Accuracy: 76%
# 101 of 100 steps: Average loss 1.356 and Accuracy: 76%
# 201 of 100 steps: Average loss 1.353 and Accuracy: 76%
# 301 of 100 steps: Average loss 1.351 and Accuracy: 76%
# 401 of 100 steps: Average loss 1.348 and Accuracy: 76%
# 501 of 100 steps: Average loss 1.345 and Accuracy: 76%
# 601 of 100 steps: Average loss 1.343 and Accuracy: 76%
# 701 of 100 steps: Average loss 1.340 and Accuracy: 76%
# 801 of 100 steps: Average loss 1.338 and Accuracy: 76%
# 901 of 100 steps: Average loss 1.336 and Accuracy: 76%
# 1001 of 100 steps: Average loss 1.333 and Accuracy: 76%
# 1101 of 100 steps: Average loss 1.331 and Accuracy: 76%
# 1201 of 100 steps: Average loss 1.329 and Accuracy: 76%
# 1301 of 100 steps: Average loss 1.326 and Accuracy: 76%
# 1401 of 100 steps: Average loss 1.324 and Accuracy: 76%
# 1501 of 100 steps: Average loss 1.322 and Accuracy: 76%
# 1601 of 100 steps: Average loss 1.319 and Accuracy: 76%
# 1701 of 100 steps: Average loss 1.317 and Accuracy: 76%
# 1801 of 100 steps: Average loss 1.314 and Accuracy: 77%
# 1901 of 100 steps: Average loss 1.312 and Accuracy: 77%
# 2001 of 100 steps: Average loss 1.310 and Accuracy: 77%
# 2101 of 100 steps: Average loss 1.307 and Accuracy: 77%
# 2201 of 100 steps: Average loss 1.305 and Accuracy: 77%
# 2301 of 100 steps: Average loss 1.302 and Accuracy: 77%
# 2401 of 100 steps: Average loss 1.300 and Accuracy: 77%
# 2501 of 100 steps: Average loss 1.298 and Accuracy: 77%
# 2601 of 100 steps: Average loss 1.296 and Accuracy: 77%
# 2701 of 100 steps: Average loss 1.293 and Accuracy: 77%
# 2801 of 100 steps: Average loss 1.291 and Accuracy: 77%
# 2901 of 100 steps: Average loss 1.289 and Accuracy: 77%
# 3001 of 100 steps: Average loss 1.287 and Accuracy: 77%
# 3101 of 100 steps: Average loss 1.285 and Accuracy: 77%
# 3201 of 100 steps: Average loss 1.282 and Accuracy: 77%
# 3301 of 100 steps: Average loss 1.280 and Accuracy: 77%
# 3401 of 100 steps: Average loss 1.278 and Accuracy: 77%
# 3501 of 100 steps: Average loss 1.276 and Accuracy: 77%
# 3601 of 100 steps: Average loss 1.274 and Accuracy: 77%
# 3701 of 100 steps: Average loss 1.272 and Accuracy: 77%
# 3801 of 100 steps: Average loss 1.270 and Accuracy: 77%
# 3901 of 100 steps: Average loss 1.268 and Accuracy: 77%
# 4001 of 100 steps: Average loss 1.267 and Accuracy: 77%
# 4101 of 100 steps: Average loss 1.264 and Accuracy: 77%
# 4201 of 100 steps: Average loss 1.263 and Accuracy: 77%
# 4301 of 100 steps: Average loss 1.261 and Accuracy: 77%
# 4401 of 100 steps: Average loss 1.258 and Accuracy: 77%
# 4501 of 100 steps: Average loss 1.256 and Accuracy: 77%
# 4601 of 100 steps: Average loss 1.255 and Accuracy: 77%
# 4701 of 100 steps: Average loss 1.252 and Accuracy: 77%
# 4801 of 100 steps: Average loss 1.250 and Accuracy: 78%
# 4901 of 100 steps: Average loss 1.248 and Accuracy: 78%
# 5001 of 100 steps: Average loss 1.246 and Accuracy: 78%
# 5101 of 100 steps: Average loss 1.245 and Accuracy: 78%
# 5201 of 100 steps: Average loss 1.243 and Accuracy: 78%
# 5301 of 100 steps: Average loss 1.241 and Accuracy: 78%
# 5401 of 100 steps: Average loss 1.239 and Accuracy: 78%
# 5501 of 100 steps: Average loss 1.237 and Accuracy: 78%
# 5601 of 100 steps: Average loss 1.235 and Accuracy: 78%
# 5701 of 100 steps: Average loss 1.233 and Accuracy: 78%
# 5801 of 100 steps: Average loss 1.231 and Accuracy: 78%
# 5901 of 100 steps: Average loss 1.229 and Accuracy: 78%
# Epoch 5 ---->
# 1 of 100 steps: Average loss 1.227 and Accuracy: 78%
# 101 of 100 steps: Average loss 1.226 and Accuracy: 78%
# 201 of 100 steps: Average loss 1.223 and Accuracy: 78%
# 301 of 100 steps: Average loss 1.221 and Accuracy: 78%
# 401 of 100 steps: Average loss 1.219 and Accuracy: 78%
# 501 of 100 steps: Average loss 1.217 and Accuracy: 78%
# 601 of 100 steps: Average loss 1.215 and Accuracy: 78%
# 701 of 100 steps: Average loss 1.213 and Accuracy: 78%
# 801 of 100 steps: Average loss 1.212 and Accuracy: 78%
# 901 of 100 steps: Average loss 1.210 and Accuracy: 78%
# 1001 of 100 steps: Average loss 1.208 and Accuracy: 78%
# 1101 of 100 steps: Average loss 1.207 and Accuracy: 78%
# 1201 of 100 steps: Average loss 1.205 and Accuracy: 78%
# 1301 of 100 steps: Average loss 1.203 and Accuracy: 78%
# 1401 of 100 steps: Average loss 1.202 and Accuracy: 78%
# 1501 of 100 steps: Average loss 1.200 and Accuracy: 78%
# 1601 of 100 steps: Average loss 1.198 and Accuracy: 78%
# 1701 of 100 steps: Average loss 1.196 and Accuracy: 78%
# 1801 of 100 steps: Average loss 1.195 and Accuracy: 78%
# 1901 of 100 steps: Average loss 1.193 and Accuracy: 79%
# 2001 of 100 steps: Average loss 1.191 and Accuracy: 79%
# 2101 of 100 steps: Average loss 1.190 and Accuracy: 79%
# 2201 of 100 steps: Average loss 1.188 and Accuracy: 79%
# 2301 of 100 steps: Average loss 1.186 and Accuracy: 79%
# 2401 of 100 steps: Average loss 1.185 and Accuracy: 79%
# 2501 of 100 steps: Average loss 1.184 and Accuracy: 79%
# 2601 of 100 steps: Average loss 1.182 and Accuracy: 79%
# 2701 of 100 steps: Average loss 1.181 and Accuracy: 79%
# 2801 of 100 steps: Average loss 1.179 and Accuracy: 79%
# 2901 of 100 steps: Average loss 1.178 and Accuracy: 79%
# 3001 of 100 steps: Average loss 1.176 and Accuracy: 79%
# 3101 of 100 steps: Average loss 1.174 and Accuracy: 79%
# 3201 of 100 steps: Average loss 1.173 and Accuracy: 79%
# 3301 of 100 steps: Average loss 1.171 and Accuracy: 79%
# 3401 of 100 steps: Average loss 1.169 and Accuracy: 79%
# 3501 of 100 steps: Average loss 1.167 and Accuracy: 79%
# 3601 of 100 steps: Average loss 1.166 and Accuracy: 79%
# 3701 of 100 steps: Average loss 1.164 and Accuracy: 79%
# 3801 of 100 steps: Average loss 1.163 and Accuracy: 79%
# 3901 of 100 steps: Average loss 1.161 and Accuracy: 79%
# 4001 of 100 steps: Average loss 1.160 and Accuracy: 79%
# 4101 of 100 steps: Average loss 1.158 and Accuracy: 79%
# 4201 of 100 steps: Average loss 1.157 and Accuracy: 79%
# 4301 of 100 steps: Average loss 1.155 and Accuracy: 79%
# 4401 of 100 steps: Average loss 1.153 and Accuracy: 79%
# 4501 of 100 steps: Average loss 1.152 and Accuracy: 79%
# 4601 of 100 steps: Average loss 1.151 and Accuracy: 79%
# 4701 of 100 steps: Average loss 1.149 and Accuracy: 79%
# 4801 of 100 steps: Average loss 1.148 and Accuracy: 79%
# 4901 of 100 steps: Average loss 1.146 and Accuracy: 79%
# 5001 of 100 steps: Average loss 1.145 and Accuracy: 79%
# 5101 of 100 steps: Average loss 1.143 and Accuracy: 79%
# 5201 of 100 steps: Average loss 1.141 and Accuracy: 79%
# 5301 of 100 steps: Average loss 1.140 and Accuracy: 79%
# 5401 of 100 steps: Average loss 1.138 and Accuracy: 79%
# 5501 of 100 steps: Average loss 1.137 and Accuracy: 79%
# 5601 of 100 steps: Average loss 1.136 and Accuracy: 79%
# 5701 of 100 steps: Average loss 1.134 and Accuracy: 79%
# 5801 of 100 steps: Average loss 1.132 and Accuracy: 79%
# 5901 of 100 steps: Average loss 1.131 and Accuracy: 79%
# Epoch 6 ---->
# 1 of 100 steps: Average loss 1.130 and Accuracy: 79%
# 101 of 100 steps: Average loss 1.128 and Accuracy: 80%
# 201 of 100 steps: Average loss 1.126 and Accuracy: 80%
# 301 of 100 steps: Average loss 1.125 and Accuracy: 80%
# 401 of 100 steps: Average loss 1.123 and Accuracy: 80%
# 501 of 100 steps: Average loss 1.122 and Accuracy: 80%
# 601 of 100 steps: Average loss 1.121 and Accuracy: 80%
# 701 of 100 steps: Average loss 1.119 and Accuracy: 80%
# 801 of 100 steps: Average loss 1.118 and Accuracy: 80%
# 901 of 100 steps: Average loss 1.117 and Accuracy: 80%
# 1001 of 100 steps: Average loss 1.115 and Accuracy: 80%
# 1101 of 100 steps: Average loss 1.114 and Accuracy: 80%
# 1201 of 100 steps: Average loss 1.113 and Accuracy: 80%
# 1301 of 100 steps: Average loss 1.111 and Accuracy: 80%
# 1401 of 100 steps: Average loss 1.110 and Accuracy: 80%
# 1501 of 100 steps: Average loss 1.109 and Accuracy: 80%
# 1601 of 100 steps: Average loss 1.107 and Accuracy: 80%
# 1701 of 100 steps: Average loss 1.106 and Accuracy: 80%
# 1801 of 100 steps: Average loss 1.104 and Accuracy: 80%
# 1901 of 100 steps: Average loss 1.103 and Accuracy: 80%
# 2001 of 100 steps: Average loss 1.102 and Accuracy: 80%
# 2101 of 100 steps: Average loss 1.100 and Accuracy: 80%
# 2201 of 100 steps: Average loss 1.099 and Accuracy: 80%
# 2301 of 100 steps: Average loss 1.097 and Accuracy: 80%
# 2401 of 100 steps: Average loss 1.096 and Accuracy: 80%
# 2501 of 100 steps: Average loss 1.095 and Accuracy: 80%
# 2601 of 100 steps: Average loss 1.094 and Accuracy: 80%
# 2701 of 100 steps: Average loss 1.093 and Accuracy: 80%
# 2801 of 100 steps: Average loss 1.091 and Accuracy: 80%
# 2901 of 100 steps: Average loss 1.090 and Accuracy: 80%
# 3001 of 100 steps: Average loss 1.089 and Accuracy: 80%
# 3101 of 100 steps: Average loss 1.088 and Accuracy: 80%
# 3201 of 100 steps: Average loss 1.087 and Accuracy: 80%
# 3301 of 100 steps: Average loss 1.085 and Accuracy: 80%
# 3401 of 100 steps: Average loss 1.084 and Accuracy: 80%
# 3501 of 100 steps: Average loss 1.083 and Accuracy: 80%
# 3601 of 100 steps: Average loss 1.082 and Accuracy: 80%
# 3701 of 100 steps: Average loss 1.081 and Accuracy: 80%
# 3801 of 100 steps: Average loss 1.079 and Accuracy: 80%
# 3901 of 100 steps: Average loss 1.078 and Accuracy: 80%
# 4001 of 100 steps: Average loss 1.077 and Accuracy: 80%
# 4101 of 100 steps: Average loss 1.075 and Accuracy: 80%
# 4201 of 100 steps: Average loss 1.074 and Accuracy: 80%
# 4301 of 100 steps: Average loss 1.073 and Accuracy: 80%
# 4401 of 100 steps: Average loss 1.072 and Accuracy: 80%
# 4501 of 100 steps: Average loss 1.070 and Accuracy: 80%
# 4601 of 100 steps: Average loss 1.069 and Accuracy: 80%
# 4701 of 100 steps: Average loss 1.068 and Accuracy: 80%
# 4801 of 100 steps: Average loss 1.067 and Accuracy: 80%
# 4901 of 100 steps: Average loss 1.066 and Accuracy: 80%
# 5001 of 100 steps: Average loss 1.064 and Accuracy: 80%
# 5101 of 100 steps: Average loss 1.063 and Accuracy: 81%
# 5201 of 100 steps: Average loss 1.062 and Accuracy: 81%
# 5301 of 100 steps: Average loss 1.061 and Accuracy: 81%
# 5401 of 100 steps: Average loss 1.059 and Accuracy: 81%
# 5501 of 100 steps: Average loss 1.058 and Accuracy: 81%
# 5601 of 100 steps: Average loss 1.057 and Accuracy: 81%
# 5701 of 100 steps: Average loss 1.056 and Accuracy: 81%
# 5801 of 100 steps: Average loss 1.055 and Accuracy: 81%
# 5901 of 100 steps: Average loss 1.054 and Accuracy: 81%
# Epoch 7 ---->
# 1 of 100 steps: Average loss 1.053 and Accuracy: 81%
# 101 of 100 steps: Average loss 1.052 and Accuracy: 81%
# 201 of 100 steps: Average loss 1.051 and Accuracy: 81%
# 301 of 100 steps: Average loss 1.050 and Accuracy: 81%
# 401 of 100 steps: Average loss 1.048 and Accuracy: 81%
# 501 of 100 steps: Average loss 1.047 and Accuracy: 81%
# 601 of 100 steps: Average loss 1.046 and Accuracy: 81%
# 701 of 100 steps: Average loss 1.045 and Accuracy: 81%
# 801 of 100 steps: Average loss 1.044 and Accuracy: 81%
# 901 of 100 steps: Average loss 1.043 and Accuracy: 81%
# 1001 of 100 steps: Average loss 1.042 and Accuracy: 81%
# 1101 of 100 steps: Average loss 1.041 and Accuracy: 81%
# 1201 of 100 steps: Average loss 1.040 and Accuracy: 81%
# 1301 of 100 steps: Average loss 1.038 and Accuracy: 81%
# 1401 of 100 steps: Average loss 1.037 and Accuracy: 81%
# 1501 of 100 steps: Average loss 1.036 and Accuracy: 81%
# 1601 of 100 steps: Average loss 1.035 and Accuracy: 81%
# 1701 of 100 steps: Average loss 1.034 and Accuracy: 81%
# 1801 of 100 steps: Average loss 1.033 and Accuracy: 81%
# 1901 of 100 steps: Average loss 1.032 and Accuracy: 81%
# 2001 of 100 steps: Average loss 1.030 and Accuracy: 81%
# 2101 of 100 steps: Average loss 1.030 and Accuracy: 81%
# 2201 of 100 steps: Average loss 1.029 and Accuracy: 81%
# 2301 of 100 steps: Average loss 1.028 and Accuracy: 81%
# 2401 of 100 steps: Average loss 1.027 and Accuracy: 81%
# 2501 of 100 steps: Average loss 1.025 and Accuracy: 81%
# 2601 of 100 steps: Average loss 1.025 and Accuracy: 81%
# 2701 of 100 steps: Average loss 1.024 and Accuracy: 81%
# 2801 of 100 steps: Average loss 1.023 and Accuracy: 81%
# 2901 of 100 steps: Average loss 1.022 and Accuracy: 81%
# 3001 of 100 steps: Average loss 1.021 and Accuracy: 81%
# 3101 of 100 steps: Average loss 1.019 and Accuracy: 81%
# 3201 of 100 steps: Average loss 1.019 and Accuracy: 81%
# 3301 of 100 steps: Average loss 1.017 and Accuracy: 81%
# 3401 of 100 steps: Average loss 1.017 and Accuracy: 81%
# 3501 of 100 steps: Average loss 1.016 and Accuracy: 81%
# 3601 of 100 steps: Average loss 1.014 and Accuracy: 81%
# 3701 of 100 steps: Average loss 1.013 and Accuracy: 81%
# 3801 of 100 steps: Average loss 1.012 and Accuracy: 81%
# 3901 of 100 steps: Average loss 1.011 and Accuracy: 81%
# 4001 of 100 steps: Average loss 1.010 and Accuracy: 81%
# 4101 of 100 steps: Average loss 1.009 and Accuracy: 81%
# 4201 of 100 steps: Average loss 1.008 and Accuracy: 81%
# 4301 of 100 steps: Average loss 1.007 and Accuracy: 81%
# 4401 of 100 steps: Average loss 1.006 and Accuracy: 81%
# 4501 of 100 steps: Average loss 1.005 and Accuracy: 81%
# 4601 of 100 steps: Average loss 1.004 and Accuracy: 81%
# 4701 of 100 steps: Average loss 1.003 and Accuracy: 81%
# 4801 of 100 steps: Average loss 1.002 and Accuracy: 81%
# 4901 of 100 steps: Average loss 1.001 and Accuracy: 81%
# 5001 of 100 steps: Average loss 1.000 and Accuracy: 81%
# 5101 of 100 steps: Average loss 0.999 and Accuracy: 81%
# 5201 of 100 steps: Average loss 0.999 and Accuracy: 81%
# 5301 of 100 steps: Average loss 0.998 and Accuracy: 82%
# 5401 of 100 steps: Average loss 0.997 and Accuracy: 82%
# 5501 of 100 steps: Average loss 0.996 and Accuracy: 82%
# 5601 of 100 steps: Average loss 0.995 and Accuracy: 82%
# 5701 of 100 steps: Average loss 0.994 and Accuracy: 82%
# 5801 of 100 steps: Average loss 0.993 and Accuracy: 82%
# 5901 of 100 steps: Average loss 0.992 and Accuracy: 82%
# Epoch 8 ---->
# 1 of 100 steps: Average loss 0.992 and Accuracy: 82%
# 101 of 100 steps: Average loss 0.990 and Accuracy: 82%
# 201 of 100 steps: Average loss 0.990 and Accuracy: 82%
# 301 of 100 steps: Average loss 0.989 and Accuracy: 82%
# 401 of 100 steps: Average loss 0.988 and Accuracy: 82%
# 501 of 100 steps: Average loss 0.987 and Accuracy: 82%
# 601 of 100 steps: Average loss 0.986 and Accuracy: 82%
# 701 of 100 steps: Average loss 0.985 and Accuracy: 82%
# 801 of 100 steps: Average loss 0.984 and Accuracy: 82%
# 901 of 100 steps: Average loss 0.983 and Accuracy: 82%
# 1001 of 100 steps: Average loss 0.982 and Accuracy: 82%
# 1101 of 100 steps: Average loss 0.981 and Accuracy: 82%
# 1201 of 100 steps: Average loss 0.980 and Accuracy: 82%
# 1301 of 100 steps: Average loss 0.979 and Accuracy: 82%
# 1401 of 100 steps: Average loss 0.979 and Accuracy: 82%
# 1501 of 100 steps: Average loss 0.978 and Accuracy: 82%
# 1601 of 100 steps: Average loss 0.977 and Accuracy: 82%
# 1701 of 100 steps: Average loss 0.976 and Accuracy: 82%
# 1801 of 100 steps: Average loss 0.975 and Accuracy: 82%
# 1901 of 100 steps: Average loss 0.974 and Accuracy: 82%
# 2001 of 100 steps: Average loss 0.974 and Accuracy: 82%
# 2101 of 100 steps: Average loss 0.973 and Accuracy: 82%
# 2201 of 100 steps: Average loss 0.972 and Accuracy: 82%
# 2301 of 100 steps: Average loss 0.971 and Accuracy: 82%
# 2401 of 100 steps: Average loss 0.970 and Accuracy: 82%
# 2501 of 100 steps: Average loss 0.969 and Accuracy: 82%
# 2601 of 100 steps: Average loss 0.968 and Accuracy: 82%
# 2701 of 100 steps: Average loss 0.967 and Accuracy: 82%
# 2801 of 100 steps: Average loss 0.967 and Accuracy: 82%
# 2901 of 100 steps: Average loss 0.966 and Accuracy: 82%
# 3001 of 100 steps: Average loss 0.965 and Accuracy: 82%
# 3101 of 100 steps: Average loss 0.964 and Accuracy: 82%
# 3201 of 100 steps: Average loss 0.964 and Accuracy: 82%
# 3301 of 100 steps: Average loss 0.963 and Accuracy: 82%
# 3401 of 100 steps: Average loss 0.962 and Accuracy: 82%
# 3501 of 100 steps: Average loss 0.961 and Accuracy: 82%
# 3601 of 100 steps: Average loss 0.960 and Accuracy: 82%
# 3701 of 100 steps: Average loss 0.959 and Accuracy: 82%
# 3801 of 100 steps: Average loss 0.958 and Accuracy: 82%
# 3901 of 100 steps: Average loss 0.958 and Accuracy: 82%
# 4001 of 100 steps: Average loss 0.957 and Accuracy: 82%
# 4101 of 100 steps: Average loss 0.956 and Accuracy: 82%
# 4201 of 100 steps: Average loss 0.955 and Accuracy: 82%
# 4301 of 100 steps: Average loss 0.954 and Accuracy: 82%
# 4401 of 100 steps: Average loss 0.953 and Accuracy: 82%
# 4501 of 100 steps: Average loss 0.952 and Accuracy: 82%
# 4601 of 100 steps: Average loss 0.951 and Accuracy: 82%
# 4701 of 100 steps: Average loss 0.951 and Accuracy: 82%
# 4801 of 100 steps: Average loss 0.950 and Accuracy: 82%
# 4901 of 100 steps: Average loss 0.949 and Accuracy: 82%
# 5001 of 100 steps: Average loss 0.948 and Accuracy: 82%
# 5101 of 100 steps: Average loss 0.947 and Accuracy: 82%
# 5201 of 100 steps: Average loss 0.946 and Accuracy: 82%
# 5301 of 100 steps: Average loss 0.946 and Accuracy: 82%
# 5401 of 100 steps: Average loss 0.945 and Accuracy: 82%
# 5501 of 100 steps: Average loss 0.944 and Accuracy: 82%
# 5601 of 100 steps: Average loss 0.943 and Accuracy: 82%
# 5701 of 100 steps: Average loss 0.942 and Accuracy: 82%
# 5801 of 100 steps: Average loss 0.942 and Accuracy: 82%
# 5901 of 100 steps: Average loss 0.941 and Accuracy: 82%
# Epoch 9 ---->
# 1 of 100 steps: Average loss 0.940 and Accuracy: 82%
# 101 of 100 steps: Average loss 0.940 and Accuracy: 82%
# 201 of 100 steps: Average loss 0.939 and Accuracy: 82%
# 301 of 100 steps: Average loss 0.938 and Accuracy: 82%
# 401 of 100 steps: Average loss 0.937 and Accuracy: 82%
# 501 of 100 steps: Average loss 0.937 and Accuracy: 82%
# 601 of 100 steps: Average loss 0.936 and Accuracy: 82%
# 701 of 100 steps: Average loss 0.935 and Accuracy: 82%
# 801 of 100 steps: Average loss 0.935 and Accuracy: 82%
# 901 of 100 steps: Average loss 0.934 and Accuracy: 82%
# 1001 of 100 steps: Average loss 0.933 and Accuracy: 82%
# 1101 of 100 steps: Average loss 0.932 and Accuracy: 82%
# 1201 of 100 steps: Average loss 0.931 and Accuracy: 82%
# 1301 of 100 steps: Average loss 0.930 and Accuracy: 82%
# 1401 of 100 steps: Average loss 0.930 and Accuracy: 82%
# 1501 of 100 steps: Average loss 0.929 and Accuracy: 82%
# 1601 of 100 steps: Average loss 0.928 and Accuracy: 82%
# 1701 of 100 steps: Average loss 0.928 and Accuracy: 82%
# 1801 of 100 steps: Average loss 0.927 and Accuracy: 82%
# 1901 of 100 steps: Average loss 0.926 and Accuracy: 82%
# 2001 of 100 steps: Average loss 0.925 and Accuracy: 83%
# 2101 of 100 steps: Average loss 0.925 and Accuracy: 83%
# 2201 of 100 steps: Average loss 0.924 and Accuracy: 83%
# 2301 of 100 steps: Average loss 0.923 and Accuracy: 83%
# 2401 of 100 steps: Average loss 0.922 and Accuracy: 83%
# 2501 of 100 steps: Average loss 0.922 and Accuracy: 83%
# 2601 of 100 steps: Average loss 0.921 and Accuracy: 83%
# 2701 of 100 steps: Average loss 0.920 and Accuracy: 83%
# 2801 of 100 steps: Average loss 0.920 and Accuracy: 83%
# 2901 of 100 steps: Average loss 0.919 and Accuracy: 83%
# 3001 of 100 steps: Average loss 0.918 and Accuracy: 83%
# 3101 of 100 steps: Average loss 0.917 and Accuracy: 83%
# 3201 of 100 steps: Average loss 0.916 and Accuracy: 83%
# 3301 of 100 steps: Average loss 0.916 and Accuracy: 83%
# 3401 of 100 steps: Average loss 0.915 and Accuracy: 83%
# 3501 of 100 steps: Average loss 0.914 and Accuracy: 83%
# 3601 of 100 steps: Average loss 0.914 and Accuracy: 83%
# 3701 of 100 steps: Average loss 0.913 and Accuracy: 83%
# 3801 of 100 steps: Average loss 0.912 and Accuracy: 83%
# 3901 of 100 steps: Average loss 0.912 and Accuracy: 83%
# 4001 of 100 steps: Average loss 0.911 and Accuracy: 83%
# 4101 of 100 steps: Average loss 0.910 and Accuracy: 83%
# 4201 of 100 steps: Average loss 0.909 and Accuracy: 83%
# 4301 of 100 steps: Average loss 0.909 and Accuracy: 83%
# 4401 of 100 steps: Average loss 0.908 and Accuracy: 83%
# 4501 of 100 steps: Average loss 0.907 and Accuracy: 83%
# 4601 of 100 steps: Average loss 0.907 and Accuracy: 83%
# 4701 of 100 steps: Average loss 0.906 and Accuracy: 83%
# 4801 of 100 steps: Average loss 0.905 and Accuracy: 83%
# 4901 of 100 steps: Average loss 0.905 and Accuracy: 83%
# 5001 of 100 steps: Average loss 0.904 and Accuracy: 83%
# 5101 of 100 steps: Average loss 0.903 and Accuracy: 83%
# 5201 of 100 steps: Average loss 0.903 and Accuracy: 83%
# 5301 of 100 steps: Average loss 0.902 and Accuracy: 83%
# 5401 of 100 steps: Average loss 0.901 and Accuracy: 83%
# 5501 of 100 steps: Average loss 0.901 and Accuracy: 83%
# 5601 of 100 steps: Average loss 0.900 and Accuracy: 83%
# 5701 of 100 steps: Average loss 0.900 and Accuracy: 83%
# 5801 of 100 steps: Average loss 0.899 and Accuracy: 83%
# 5901 of 100 steps: Average loss 0.898 and Accuracy: 83%
# Epoch 10 ---->
# 1 of 100 steps: Average loss 0.897 and Accuracy: 83%
# 101 of 100 steps: Average loss 0.896 and Accuracy: 83%
# 201 of 100 steps: Average loss 0.896 and Accuracy: 83%
# 301 of 100 steps: Average loss 0.895 and Accuracy: 83%
# 401 of 100 steps: Average loss 0.894 and Accuracy: 83%
# 501 of 100 steps: Average loss 0.894 and Accuracy: 83%
# 601 of 100 steps: Average loss 0.893 and Accuracy: 83%
# 701 of 100 steps: Average loss 0.892 and Accuracy: 83%
# 801 of 100 steps: Average loss 0.891 and Accuracy: 83%
# 901 of 100 steps: Average loss 0.891 and Accuracy: 83%
# 1001 of 100 steps: Average loss 0.890 and Accuracy: 83%
# 1101 of 100 steps: Average loss 0.889 and Accuracy: 83%
# 1201 of 100 steps: Average loss 0.889 and Accuracy: 83%
# 1301 of 100 steps: Average loss 0.888 and Accuracy: 83%
# 1401 of 100 steps: Average loss 0.887 and Accuracy: 83%
# 1501 of 100 steps: Average loss 0.886 and Accuracy: 83%
# 1601 of 100 steps: Average loss 0.886 and Accuracy: 83%
# 1701 of 100 steps: Average loss 0.885 and Accuracy: 83%
# 1801 of 100 steps: Average loss 0.884 and Accuracy: 83%
# 1901 of 100 steps: Average loss 0.884 and Accuracy: 83%
# 2001 of 100 steps: Average loss 0.883 and Accuracy: 83%
# 2101 of 100 steps: Average loss 0.883 and Accuracy: 83%
# 2201 of 100 steps: Average loss 0.882 and Accuracy: 83%
# 2301 of 100 steps: Average loss 0.881 and Accuracy: 83%
# 2401 of 100 steps: Average loss 0.881 and Accuracy: 83%
# 2501 of 100 steps: Average loss 0.880 and Accuracy: 83%
# 2601 of 100 steps: Average loss 0.880 and Accuracy: 83%
# 2701 of 100 steps: Average loss 0.879 and Accuracy: 83%
# 2801 of 100 steps: Average loss 0.878 and Accuracy: 83%
# 2901 of 100 steps: Average loss 0.878 and Accuracy: 83%
# 3001 of 100 steps: Average loss 0.877 and Accuracy: 83%
# 3101 of 100 steps: Average loss 0.876 and Accuracy: 83%
# 3201 of 100 steps: Average loss 0.876 and Accuracy: 83%
# 3301 of 100 steps: Average loss 0.875 and Accuracy: 83%
# 3401 of 100 steps: Average loss 0.875 and Accuracy: 83%
# 3501 of 100 steps: Average loss 0.874 and Accuracy: 83%
# 3601 of 100 steps: Average loss 0.874 and Accuracy: 83%
# 3701 of 100 steps: Average loss 0.873 and Accuracy: 83%
# 3801 of 100 steps: Average loss 0.872 and Accuracy: 83%
# 3901 of 100 steps: Average loss 0.872 and Accuracy: 83%
# 4001 of 100 steps: Average loss 0.872 and Accuracy: 83%
# 4101 of 100 steps: Average loss 0.871 and Accuracy: 83%
# 4201 of 100 steps: Average loss 0.871 and Accuracy: 83%
# 4301 of 100 steps: Average loss 0.870 and Accuracy: 83%
# 4401 of 100 steps: Average loss 0.869 and Accuracy: 83%
# 4501 of 100 steps: Average loss 0.869 and Accuracy: 83%
# 4601 of 100 steps: Average loss 0.868 and Accuracy: 83%
# 4701 of 100 steps: Average loss 0.868 and Accuracy: 83%
# 4801 of 100 steps: Average loss 0.867 and Accuracy: 83%
# 4901 of 100 steps: Average loss 0.866 and Accuracy: 83%
# 5001 of 100 steps: Average loss 0.866 and Accuracy: 83%
# 5101 of 100 steps: Average loss 0.866 and Accuracy: 83%
# 5201 of 100 steps: Average loss 0.865 and Accuracy: 83%
# 5301 of 100 steps: Average loss 0.864 and Accuracy: 83%
# 5401 of 100 steps: Average loss 0.864 and Accuracy: 83%
# 5501 of 100 steps: Average loss 0.863 and Accuracy: 83%
# 5601 of 100 steps: Average loss 0.862 and Accuracy: 83%
# 5701 of 100 steps: Average loss 0.862 and Accuracy: 83%
# 5801 of 100 steps: Average loss 0.861 and Accuracy: 83%
# 5901 of 100 steps: Average loss 0.861 and Accuracy: 83%
# 2821.833461046219

# %%
# Test the CNN
print('Testing the CNN....')
start = time.time()
test_lossVals = []
test_accuVals = []
loss = 0 
num_correct = 0
for i, (img, label) in enumerate(zip(test_images, test_labels)):
  _, l1, accu = feed_forward(img, label)
  loss += l1
  num_correct += accu
  test_lossVals.append(loss / (i+1))
  test_accuVals.append((num_correct * 100) / (i+1))

num_tests = len(test_images)
print('Test loss: ', loss / num_tests)
print('Test accuracy: ', num_correct / num_tests)
print(time.time() - start)
# Out:
# Testing the CNN....
# Test loss:  0.6456900451923392
# Test accuracy:  0.85
# 14.661759853363037

# %%
# Plots for testing

plt.plot(test_accuVals)
plt.title("Accuracy vs. Iterations")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.show()

plt.plot(test_lossVals)
plt.title("Loss vs Iterations")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
# Plots for training

plt.plot(accuVals)
plt.title("Accuracy vs. Iterations")
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.show()

plt.plot(lossVals)
plt.title("Loss vs Iterations")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
# Add a file called accu_loss.csv into google colab's files
# Save training accuracies and loss

import csv

with open('/content/drive/My Drive/OptML/CSVs/SGD-Nesterov/sgd-nesterov-training-0001.csv', mode='w') as accu_loss:
    accu_loss_writer = csv.writer(accu_loss, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    for accu, loss in zip(accuVals, lossVals):
      accu_loss_writer.writerow([accu, loss])
  
print ("Finished writing")
# Out:
# Finished writing

# %%
# Add a file called accu_loss.csv into google colab's files
# Save testing accuracies and loss

import csv

with open('/content/drive/My Drive/OptML/CSVs/SGD-Nesterov/sgd-nesterov-testing-0001.csv', mode='w') as accu_loss:
    accu_loss_writer = csv.writer(accu_loss, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    for accu, loss in zip(test_accuVals, test_lossVals):
      accu_loss_writer.writerow([accu, loss])

print ("Finished writing")
# Out:
# Finished writing
